# %% [markdown]
# # Wide ResNet 28 10 with Cutout, without probability
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)

# %% [markdown]
# ## 1.2. Import

# %%
import torch, torchvision, augmentation, train
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128
cifar_dir = '../../../../data/OCR/Jason/cifar10/'

# %%
pre_transform = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip()]
post_transform = [augmentation.Cutout(1, 8), 
                  transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])]

train_transform = transforms.Compose(pre_transform + post_transform)

test_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False)

test_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=False)

# %% [markdown]
# # 3. Train Model

# %%
depth = 28
widen_factor = 10
dropout_rate = 0.3
num_classes = 10

gpu_id = 6

print_freq = 60
epoch_print = 10

save = False
epochs = 201

lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov = True
milestones = [60, 120, 160]

# %%
WRN_28_10 = train.Wide_ResNet(depth, widen_factor, dropout_rate, num_classes, gpu_id, print_freq, epoch_print)
WRN_28_10.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay, nesterov, milestones)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 1.8030, Test Loss : 1.9852, Train Acc : 31.2500, Test Acc : 26.1200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 1.7183, Test Loss : 1.8775, Train Acc : 40.6250, Test Acc : 32.5000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 1.6486, Test Loss : 1.7599, Train Acc : 39.8438, Test Acc : 39.6000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 1.4902, Test Loss : 1.6372, Train Acc : 53.9062, Test Acc : 41.3900
# Iteration : 300 - Train Loss : 1.6127, Test Loss : 1.6831, Train Acc : 39.8438, Test Acc : 41.0300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 1.3558, Test Loss : 1.3636, Train Acc : 44.5312, Test Acc : 51.2600
# Epoch 11 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.5306, Test Loss : 0.5629, Train Acc : 80.4688, Test Acc : 80.6600
# Iteration : 120 - Train Loss : 0.5877, Test Loss : 0.6692, Train Acc : 75.7812, Test Acc : 77.7700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.6111, Test Loss : 0.5233, Train Acc : 80.4688, Test Acc : 82.2200
# Iteration : 240 - Train Loss : 0.7748, Test Loss : 0.5640, Train Acc : 73.4375, Test Acc : 82.0500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.6346, Test Loss : 0.4892, Train Acc : 78.9062, Test Acc : 83.1900
# Iteration : 360 - Train Loss : 0.6251, Test Loss : 0.6007, Train Acc : 81.2500, Test Acc : 79.6100
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.5005, Test Loss : 0.4388, Train Acc : 81.2500, Test Acc : 85.3200
# Iteration : 120 - Train Loss : 0.5848, Test Loss : 0.4293, Train Acc : 80.4688, Test Acc : 84.9100
# Iteration : 180 - Train Loss : 0.4074, Test Loss : 0.5582, Train Acc : 86.7188, Test Acc : 82.6000
# Iteration : 240 - Train Loss : 0.4582, Test Loss : 0.6450, Train Acc : 85.9375, Test Acc : 80.4000
# Iteration : 300 - Train Loss : 0.4528, Test Loss : 0.4649, Train Acc : 82.0312, Test Acc : 84.2000
# Iteration : 360 - Train Loss : 0.6360, Test Loss : 0.6030, Train Acc : 83.5938, Test Acc : 81.1100
# Epoch 31 Started...
# Iteration : 60 - Train Loss : 0.4535, Test Loss : 0.5771, Train Acc : 85.9375, Test Acc : 81.7100
# Iteration : 120 - Train Loss : 0.4484, Test Loss : 0.6344, Train Acc : 85.9375, Test Acc : 80.2800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.3870, Test Loss : 0.4171, Train Acc : 89.0625, Test Acc : 86.3900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.4921, Test Loss : 0.3671, Train Acc : 83.5938, Test Acc : 87.4200
# Iteration : 300 - Train Loss : 0.5923, Test Loss : 0.4365, Train Acc : 79.6875, Test Acc : 85.4500
# Iteration : 360 - Train Loss : 0.4506, Test Loss : 0.5200, Train Acc : 84.3750, Test Acc : 84.0800
# Epoch 41 Started...
# Iteration : 60 - Train Loss : 0.5301, Test Loss : 0.4337, Train Acc : 82.8125, Test Acc : 85.4400
# Iteration : 120 - Train Loss : 0.3757, Test Loss : 0.5086, Train Acc : 87.5000, Test Acc : 83.8600
# Iteration : 180 - Train Loss : 0.4568, Test Loss : 0.4033, Train Acc : 85.1562, Test Acc : 86.3000
# Iteration : 240 - Train Loss : 0.4432, Test Loss : 0.5145, Train Acc : 83.5938, Test Acc : 84.2000
# Iteration : 300 - Train Loss : 0.3194, Test Loss : 0.4326, Train Acc : 89.0625, Test Acc : 84.9300
# Iteration : 360 - Train Loss : 0.5174, Test Loss : 0.7488, Train Acc : 78.9062, Test Acc : 77.9700
# Epoch 51 Started...
# Iteration : 60 - Train Loss : 0.4193, Test Loss : 0.4087, Train Acc : 85.9375, Test Acc : 86.6600
# Iteration : 120 - Train Loss : 0.5240, Test Loss : 0.4751, Train Acc : 81.2500, Test Acc : 84.2600
# Iteration : 180 - Train Loss : 0.4908, Test Loss : 0.4150, Train Acc : 80.4688, Test Acc : 86.2500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.4030, Test Loss : 0.3579, Train Acc : 86.7188, Test Acc : 87.7900
# Iteration : 300 - Train Loss : 0.5766, Test Loss : 0.5138, Train Acc : 78.9062, Test Acc : 82.8700
# Iteration : 360 - Train Loss : 0.3619, Test Loss : 0.5347, Train Acc : 85.9375, Test Acc : 82.0700
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.2410, Test Loss : 0.2332, Train Acc : 93.7500, Test Acc : 91.8800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.2900, Test Loss : 0.2050, Train Acc : 88.2812, Test Acc : 93.1700
# Iteration : 180 - Train Loss : 0.3312, Test Loss : 0.2070, Train Acc : 87.5000, Test Acc : 93.0800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.3056, Test Loss : 0.2055, Train Acc : 87.5000, Test Acc : 93.3800
# Iteration : 300 - Train Loss : 0.2647, Test Loss : 0.2079, Train Acc : 88.2812, Test Acc : 92.8800
# Iteration : 360 - Train Loss : 0.2474, Test Loss : 0.1912, Train Acc : 92.1875, Test Acc : 93.2300
# Epoch 71 Started...
# Iteration : 60 - Train Loss : 0.1652, Test Loss : 0.2224, Train Acc : 94.5312, Test Acc : 92.7100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1928, Test Loss : 0.2035, Train Acc : 93.7500, Test Acc : 93.4100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.2763, Test Loss : 0.1890, Train Acc : 92.1875, Test Acc : 93.9100
# Iteration : 240 - Train Loss : 0.2594, Test Loss : 0.1865, Train Acc : 92.9688, Test Acc : 93.6500
# Iteration : 300 - Train Loss : 0.1901, Test Loss : 0.2028, Train Acc : 93.7500, Test Acc : 93.1800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.1753, Test Loss : 0.1813, Train Acc : 93.7500, Test Acc : 94.0100
# Epoch 81 Started...
# Iteration : 60 - Train Loss : 0.2939, Test Loss : 0.2465, Train Acc : 89.8438, Test Acc : 92.3700
# Iteration : 120 - Train Loss : 0.2371, Test Loss : 0.2063, Train Acc : 92.1875, Test Acc : 93.4500
# Iteration : 180 - Train Loss : 0.2589, Test Loss : 0.1978, Train Acc : 89.0625, Test Acc : 93.6200
# Iteration : 240 - Train Loss : 0.2426, Test Loss : 0.2179, Train Acc : 92.9688, Test Acc : 92.7800
# Iteration : 300 - Train Loss : 0.2213, Test Loss : 0.2112, Train Acc : 92.1875, Test Acc : 93.1700
# Iteration : 360 - Train Loss : 0.1943, Test Loss : 0.1848, Train Acc : 93.7500, Test Acc : 93.9000
# Epoch 91 Started...
# Iteration : 60 - Train Loss : 0.0914, Test Loss : 0.2311, Train Acc : 96.8750, Test Acc : 92.6000
# Iteration : 120 - Train Loss : 0.2676, Test Loss : 0.2283, Train Acc : 90.6250, Test Acc : 92.7000
# Iteration : 180 - Train Loss : 0.1440, Test Loss : 0.2125, Train Acc : 95.3125, Test Acc : 93.0900
# Iteration : 240 - Train Loss : 0.1779, Test Loss : 0.2323, Train Acc : 92.9688, Test Acc : 92.6700
# Iteration : 300 - Train Loss : 0.2609, Test Loss : 0.2517, Train Acc : 90.6250, Test Acc : 92.3200
# Iteration : 360 - Train Loss : 0.1755, Test Loss : 0.2404, Train Acc : 96.0938, Test Acc : 92.3600
# Epoch 101 Started...
# Iteration : 60 - Train Loss : 0.3131, Test Loss : 0.2233, Train Acc : 88.2812, Test Acc : 92.8400
# Iteration : 120 - Train Loss : 0.1770, Test Loss : 0.2599, Train Acc : 92.1875, Test Acc : 92.1200
# Iteration : 180 - Train Loss : 0.3182, Test Loss : 0.2248, Train Acc : 90.6250, Test Acc : 92.9400
# Iteration : 240 - Train Loss : 0.3146, Test Loss : 0.2697, Train Acc : 87.5000, Test Acc : 91.8300
# Iteration : 300 - Train Loss : 0.1817, Test Loss : 0.2357, Train Acc : 92.9688, Test Acc : 92.4200
# Iteration : 360 - Train Loss : 0.1143, Test Loss : 0.2187, Train Acc : 96.0938, Test Acc : 93.2000
# Epoch 111 Started...
# Iteration : 60 - Train Loss : 0.1559, Test Loss : 0.3015, Train Acc : 95.3125, Test Acc : 91.4000
# Iteration : 120 - Train Loss : 0.2050, Test Loss : 0.2045, Train Acc : 91.4062, Test Acc : 93.4600
# Iteration : 180 - Train Loss : 0.2336, Test Loss : 0.2034, Train Acc : 92.1875, Test Acc : 93.6100
# Iteration : 240 - Train Loss : 0.2059, Test Loss : 0.2447, Train Acc : 94.5312, Test Acc : 92.5900
# Iteration : 300 - Train Loss : 0.2291, Test Loss : 0.2448, Train Acc : 93.7500, Test Acc : 92.3300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.1629, Test Loss : 0.1864, Train Acc : 93.7500, Test Acc : 94.0300
# Epoch 121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0794, Test Loss : 0.1412, Train Acc : 96.8750, Test Acc : 95.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1385, Test Loss : 0.1307, Train Acc : 94.5312, Test Acc : 95.8300
# Iteration : 180 - Train Loss : 0.1467, Test Loss : 0.1272, Train Acc : 94.5312, Test Acc : 95.7800
# Iteration : 240 - Train Loss : 0.0630, Test Loss : 0.1275, Train Acc : 98.4375, Test Acc : 95.8300
# Iteration : 300 - Train Loss : 0.0652, Test Loss : 0.1309, Train Acc : 97.6562, Test Acc : 95.8000
# Iteration : 360 - Train Loss : 0.1040, Test Loss : 0.1319, Train Acc : 96.8750, Test Acc : 95.7900
# Epoch 131 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0330, Test Loss : 0.1216, Train Acc : 99.2188, Test Acc : 96.3100
# Iteration : 120 - Train Loss : 0.0761, Test Loss : 0.1263, Train Acc : 97.6562, Test Acc : 96.1500
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0699, Test Loss : 0.1190, Train Acc : 96.8750, Test Acc : 96.5000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.0684, Test Loss : 0.1173, Train Acc : 98.4375, Test Acc : 96.5400
# Iteration : 300 - Train Loss : 0.0613, Test Loss : 0.1203, Train Acc : 98.4375, Test Acc : 96.4400
# Iteration : 360 - Train Loss : 0.0942, Test Loss : 0.1268, Train Acc : 96.8750, Test Acc : 96.3300
# Epoch 141 Started...
# Iteration : 60 - Train Loss : 0.1110, Test Loss : 0.1301, Train Acc : 96.8750, Test Acc : 96.1100
# Iteration : 120 - Train Loss : 0.0617, Test Loss : 0.1233, Train Acc : 98.4375, Test Acc : 96.4500
# Iteration : 180 - Train Loss : 0.1199, Test Loss : 0.1198, Train Acc : 97.6562, Test Acc : 96.4700
# Iteration : 240 - Train Loss : 0.0392, Test Loss : 0.1278, Train Acc : 98.4375, Test Acc : 96.1900
# Iteration : 300 - Train Loss : 0.0573, Test Loss : 0.1216, Train Acc : 97.6562, Test Acc : 96.4500
# Iteration : 360 - Train Loss : 0.0666, Test Loss : 0.1268, Train Acc : 96.8750, Test Acc : 96.4600
# Epoch 151 Started...
# Iteration : 60 - Train Loss : 0.0565, Test Loss : 0.1410, Train Acc : 97.6562, Test Acc : 96.0900
# Iteration : 120 - Train Loss : 0.0523, Test Loss : 0.1374, Train Acc : 97.6562, Test Acc : 96.0200
# Iteration : 180 - Train Loss : 0.0380, Test Loss : 0.1347, Train Acc : 97.6562, Test Acc : 96.2800
# Iteration : 240 - Train Loss : 0.0539, Test Loss : 0.1267, Train Acc : 99.2188, Test Acc : 96.2400
# Iteration : 300 - Train Loss : 0.0509, Test Loss : 0.1385, Train Acc : 97.6562, Test Acc : 95.9700
# Iteration : 360 - Train Loss : 0.0239, Test Loss : 0.1319, Train Acc : 98.4375, Test Acc : 96.1800
# Epoch 161 Started...
# Iteration : 60 - Train Loss : 0.0659, Test Loss : 0.1245, Train Acc : 97.6562, Test Acc : 96.4500
# Iteration : 120 - Train Loss : 0.0358, Test Loss : 0.1244, Train Acc : 99.2188, Test Acc : 96.4900
# Iteration : 180 - Train Loss : 0.0606, Test Loss : 0.1236, Train Acc : 97.6562, Test Acc : 96.5200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.0071, Test Loss : 0.1219, Train Acc : 100.0000, Test Acc : 96.5800
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.0440, Test Loss : 0.1194, Train Acc : 99.2188, Test Acc : 96.7600
# Iteration : 360 - Train Loss : 0.0324, Test Loss : 0.1207, Train Acc : 99.2188, Test Acc : 96.6800
# Epoch 171 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0196, Test Loss : 0.1176, Train Acc : 99.2188, Test Acc : 96.8100
# Iteration : 120 - Train Loss : 0.0162, Test Loss : 0.1169, Train Acc : 99.2188, Test Acc : 96.6400
# Iteration : 180 - Train Loss : 0.0142, Test Loss : 0.1172, Train Acc : 100.0000, Test Acc : 96.6900
# Iteration : 240 - Train Loss : 0.0278, Test Loss : 0.1176, Train Acc : 99.2188, Test Acc : 96.5800
# Iteration : 300 - Train Loss : 0.1146, Test Loss : 0.1150, Train Acc : 96.0938, Test Acc : 96.7200
# Iteration : 360 - Train Loss : 0.0169, Test Loss : 0.1153, Train Acc : 99.2188, Test Acc : 96.7200
# Epoch 181 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0283, Test Loss : 0.1179, Train Acc : 98.4375, Test Acc : 96.8400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0154, Test Loss : 0.1178, Train Acc : 99.2188, Test Acc : 96.9100
# Iteration : 180 - Train Loss : 0.0079, Test Loss : 0.1181, Train Acc : 100.0000, Test Acc : 96.8700
# Iteration : 240 - Train Loss : 0.0054, Test Loss : 0.1174, Train Acc : 100.0000, Test Acc : 96.8400
# Iteration : 300 - Train Loss : 0.0354, Test Loss : 0.1194, Train Acc : 98.4375, Test Acc : 96.7800
# Iteration : 360 - Train Loss : 0.0315, Test Loss : 0.1195, Train Acc : 99.2188, Test Acc : 96.7900
# Epoch 191 Started...
# Iteration : 60 - Train Loss : 0.0225, Test Loss : 0.1181, Train Acc : 98.4375, Test Acc : 96.8400
# Iteration : 120 - Train Loss : 0.0274, Test Loss : 0.1170, Train Acc : 98.4375, Test Acc : 96.8800
# Iteration : 180 - Train Loss : 0.0603, Test Loss : 0.1187, Train Acc : 98.4375, Test Acc : 96.8400
# Iteration : 240 - Train Loss : 0.0242, Test Loss : 0.1172, Train Acc : 99.2188, Test Acc : 96.7400
# Iteration : 300 - Train Loss : 0.0051, Test Loss : 0.1169, Train Acc : 100.0000, Test Acc : 96.7600
# Iteration : 360 - Train Loss : 0.0057, Test Loss : 0.1172, Train Acc : 100.0000, Test Acc : 96.8200
# Epoch 201 Started...
# Iteration : 60 - Train Loss : 0.0241, Test Loss : 0.1197, Train Acc : 99.2188, Test Acc : 96.8400
# Iteration : 120 - Train Loss : 0.0240, Test Loss : 0.1206, Train Acc : 99.2188, Test Acc : 96.9000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0202, Test Loss : 0.1181, Train Acc : 99.2188, Test Acc : 96.9800
# Iteration : 240 - Train Loss : 0.0414, Test Loss : 0.1210, Train Acc : 98.4375, Test Acc : 96.9000
# Iteration : 300 - Train Loss : 0.0347, Test Loss : 0.1192, Train Acc : 99.2188, Test Acc : 96.9300
# Iteration : 360 - Train Loss : 0.0097, Test Loss : 0.1221, Train Acc : 100.0000, Test Acc : 96.7800

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(WRN_28_10.train_losses, label='Train')
test_lossline, = plt.plot(WRN_28_10.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(WRN_28_10.train_acc, label='Train')
test_accline, = plt.plot(WRN_28_10.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')

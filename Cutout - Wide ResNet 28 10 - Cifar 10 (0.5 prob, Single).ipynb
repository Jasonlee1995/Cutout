# %% [markdown]
# # Wide ResNet 28 10 with Cutout, 0.5 probability
#
# # 1. Environment Setup
# ## 1.0. Check GPU

# %%
# !nvcc --version
# Out:
# nvcc: NVIDIA (R) Cuda compiler driver
# Copyright (c) 2005-2020 NVIDIA Corporation
# Built on Mon_Oct_12_20:09:46_PDT_2020
# Cuda compilation tools, release 11.1, V11.1.105
# Build cuda_11.1.TC455_06.29190527_0

# %% [markdown]
# ## 1.1. Install matplotlib

# %%
# !pip install matplotlib
# Out:
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.8/site-packages (3.4.2)
# Requirement already satisfied: pyparsing>=2.2.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.4.7)
# Requirement already satisfied: numpy>=1.16 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.19.2)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (0.10.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (2.8.1)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.8/site-packages (from matplotlib) (8.1.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.8/site-packages (from cycler>=0.10->matplotlib) (1.15.0)

# %% [markdown]
# ## 1.2. Import

# %%
import torch, torchvision, augmentation, train
import torchvision.transforms as transforms
import matplotlib.pyplot as plt

# Ignore Warning
import warnings
warnings.filterwarnings(action='ignore')

# %% [markdown]
# # 2. Data Preprocessing

# %%
batch_size = 128
cifar_dir = '../../../../data/OCR/Jason/cifar10/'

# %%
pre_transform = [transforms.RandomCrop(32, padding=4), transforms.RandomHorizontalFlip()]
post_transform = [augmentation.Cutout(0.5, 8), 
                  transforms.ToTensor(), transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])]

train_transform = transforms.Compose(pre_transform + post_transform)

test_transform = transforms.Compose([transforms.ToTensor(), 
                                     transforms.Normalize(mean=[0.4921, 0.4828, 0.4474], std=[0.1950, 0.1922, 0.1940])])

train_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=True, download=False, transform=train_transform)
train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=batch_size, shuffle=True, pin_memory=False)

test_dataset = torchvision.datasets.CIFAR10(cifar_dir, train=False, download=False, transform=test_transform)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=batch_size, shuffle=False, pin_memory=False)

# %% [markdown]
# # 3. Train Model

# %%
depth = 28
widen_factor = 10
dropout_rate = 0.3
num_classes = 10

gpu_id = 7

print_freq = 60
epoch_print = 10

save = False
epochs = 201

lr = 0.1
momentum = 0.9
weight_decay = 0.0005
nesterov = True
milestones = [60, 120, 160]

# %%
WRN_28_10 = train.Wide_ResNet(depth, widen_factor, dropout_rate, num_classes, gpu_id, print_freq, epoch_print)
WRN_28_10.train(train_loader, test_loader, save, epochs, lr, momentum, weight_decay, nesterov, milestones)
# Out:
# Epoch 1 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 1.7958, Test Loss : 2.0202, Train Acc : 32.8125, Test Acc : 28.6100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 1.6318, Test Loss : 1.8230, Train Acc : 37.5000, Test Acc : 35.8900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 1.6853, Test Loss : 1.6179, Train Acc : 42.9688, Test Acc : 42.2300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 1.4484, Test Loss : 1.6572, Train Acc : 45.3125, Test Acc : 43.1600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 1.3845, Test Loss : 1.4034, Train Acc : 48.4375, Test Acc : 50.7100
# Iteration : 360 - Train Loss : 1.2432, Test Loss : 1.6753, Train Acc : 53.9062, Test Acc : 47.3000
# Epoch 11 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.5181, Test Loss : 0.6504, Train Acc : 82.8125, Test Acc : 77.8400
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.4856, Test Loss : 0.5966, Train Acc : 79.6875, Test Acc : 80.1600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.5309, Test Loss : 0.5725, Train Acc : 82.8125, Test Acc : 80.7900
# Iteration : 240 - Train Loss : 0.5896, Test Loss : 0.6678, Train Acc : 79.6875, Test Acc : 78.0200
# Iteration : 300 - Train Loss : 0.4202, Test Loss : 0.7576, Train Acc : 85.9375, Test Acc : 76.7300
# Iteration : 360 - Train Loss : 0.6416, Test Loss : 0.6997, Train Acc : 78.1250, Test Acc : 75.5100
# Epoch 21 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.2667, Test Loss : 0.5284, Train Acc : 92.1875, Test Acc : 83.0100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.3589, Test Loss : 0.4504, Train Acc : 85.1562, Test Acc : 84.9000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.4923, Test Loss : 0.4398, Train Acc : 84.3750, Test Acc : 85.8600
# Iteration : 240 - Train Loss : 0.3972, Test Loss : 0.5519, Train Acc : 85.9375, Test Acc : 82.1700
# Iteration : 300 - Train Loss : 0.3801, Test Loss : 0.5073, Train Acc : 88.2812, Test Acc : 83.2400
# Iteration : 360 - Train Loss : 0.2627, Test Loss : 0.5547, Train Acc : 89.8438, Test Acc : 82.4300
# Epoch 31 Started...
# Iteration : 60 - Train Loss : 0.3859, Test Loss : 0.6319, Train Acc : 85.9375, Test Acc : 79.3600
# Iteration : 120 - Train Loss : 0.4842, Test Loss : 0.5074, Train Acc : 83.5938, Test Acc : 83.4700
# Iteration : 180 - Train Loss : 0.4539, Test Loss : 0.4572, Train Acc : 82.8125, Test Acc : 84.7500
# Iteration : 240 - Train Loss : 0.4387, Test Loss : 0.5549, Train Acc : 85.1562, Test Acc : 82.6000
# Iteration : 300 - Train Loss : 0.5039, Test Loss : 0.5737, Train Acc : 85.9375, Test Acc : 81.5200
# Iteration : 360 - Train Loss : 0.3792, Test Loss : 0.6873, Train Acc : 89.0625, Test Acc : 78.8100
# Epoch 41 Started...
# Iteration : 60 - Train Loss : 0.4316, Test Loss : 0.5404, Train Acc : 85.1562, Test Acc : 82.9100
# Iteration : 120 - Train Loss : 0.4570, Test Loss : 0.5840, Train Acc : 82.8125, Test Acc : 82.2300
# Iteration : 180 - Train Loss : 0.3605, Test Loss : 0.4416, Train Acc : 85.1562, Test Acc : 85.2600
# Iteration : 240 - Train Loss : 0.1770, Test Loss : 0.4419, Train Acc : 93.7500, Test Acc : 85.2000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.3741, Test Loss : 0.3909, Train Acc : 85.9375, Test Acc : 87.0000
# Iteration : 360 - Train Loss : 0.4020, Test Loss : 0.4487, Train Acc : 85.1562, Test Acc : 85.1600
# Epoch 51 Started...
# Iteration : 60 - Train Loss : 0.4255, Test Loss : 0.5362, Train Acc : 83.5938, Test Acc : 83.2500
# Iteration : 120 - Train Loss : 0.4757, Test Loss : 0.4041, Train Acc : 84.3750, Test Acc : 86.2200
# Iteration : 180 - Train Loss : 0.4907, Test Loss : 0.5174, Train Acc : 83.5938, Test Acc : 84.2900
# Iteration : 240 - Train Loss : 0.3470, Test Loss : 0.4762, Train Acc : 89.8438, Test Acc : 84.5300
# Iteration : 300 - Train Loss : 0.3442, Test Loss : 0.4791, Train Acc : 88.2812, Test Acc : 85.3200
# Iteration : 360 - Train Loss : 0.3224, Test Loss : 0.4587, Train Acc : 87.5000, Test Acc : 84.4300
# Epoch 61 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.2500, Test Loss : 0.2297, Train Acc : 91.4062, Test Acc : 92.1900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.2237, Test Loss : 0.2141, Train Acc : 92.9688, Test Acc : 92.8700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.1616, Test Loss : 0.1991, Train Acc : 96.0938, Test Acc : 93.2700
# Iteration : 240 - Train Loss : 0.2978, Test Loss : 0.1991, Train Acc : 88.2812, Test Acc : 93.1900
# Iteration : 300 - Train Loss : 0.2545, Test Loss : 0.2045, Train Acc : 89.8438, Test Acc : 93.2000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.1576, Test Loss : 0.1970, Train Acc : 95.3125, Test Acc : 93.4400
# Epoch 71 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1976, Test Loss : 0.1852, Train Acc : 94.5312, Test Acc : 94.0900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.1352, Test Loss : 0.1809, Train Acc : 96.8750, Test Acc : 94.1100
# Iteration : 180 - Train Loss : 0.0868, Test Loss : 0.2000, Train Acc : 95.3125, Test Acc : 93.7600
# Iteration : 240 - Train Loss : 0.1580, Test Loss : 0.1997, Train Acc : 92.9688, Test Acc : 93.6900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.1689, Test Loss : 0.1852, Train Acc : 92.1875, Test Acc : 94.1200
# Iteration : 360 - Train Loss : 0.2542, Test Loss : 0.2020, Train Acc : 90.6250, Test Acc : 93.4800
# Epoch 81 Started...
# Iteration : 60 - Train Loss : 0.1789, Test Loss : 0.2057, Train Acc : 92.9688, Test Acc : 93.7400
# Iteration : 120 - Train Loss : 0.2008, Test Loss : 0.2098, Train Acc : 93.7500, Test Acc : 93.1300
# Iteration : 180 - Train Loss : 0.1438, Test Loss : 0.2155, Train Acc : 93.7500, Test Acc : 93.2100
# Iteration : 240 - Train Loss : 0.1113, Test Loss : 0.2068, Train Acc : 96.8750, Test Acc : 93.3300
# Iteration : 300 - Train Loss : 0.1594, Test Loss : 0.2212, Train Acc : 93.7500, Test Acc : 93.3800
# Iteration : 360 - Train Loss : 0.1378, Test Loss : 0.2445, Train Acc : 94.5312, Test Acc : 92.5200
# Epoch 91 Started...
# Iteration : 60 - Train Loss : 0.1253, Test Loss : 0.2288, Train Acc : 95.3125, Test Acc : 93.2900
# Iteration : 120 - Train Loss : 0.2413, Test Loss : 0.1966, Train Acc : 91.4062, Test Acc : 93.8000
# Iteration : 180 - Train Loss : 0.1995, Test Loss : 0.2427, Train Acc : 92.1875, Test Acc : 92.3200
# Iteration : 240 - Train Loss : 0.2422, Test Loss : 0.2683, Train Acc : 92.1875, Test Acc : 91.8600
# Iteration : 300 - Train Loss : 0.1581, Test Loss : 0.2110, Train Acc : 94.5312, Test Acc : 93.3400
# Iteration : 360 - Train Loss : 0.1188, Test Loss : 0.2717, Train Acc : 96.0938, Test Acc : 92.0300
# Epoch 101 Started...
# Iteration : 60 - Train Loss : 0.1020, Test Loss : 0.2559, Train Acc : 96.8750, Test Acc : 92.4300
# Iteration : 120 - Train Loss : 0.1197, Test Loss : 0.2068, Train Acc : 95.3125, Test Acc : 93.7500
# Iteration : 180 - Train Loss : 0.1473, Test Loss : 0.2223, Train Acc : 96.0938, Test Acc : 93.1100
# Iteration : 240 - Train Loss : 0.1174, Test Loss : 0.2106, Train Acc : 96.8750, Test Acc : 93.6900
# Iteration : 300 - Train Loss : 0.1221, Test Loss : 0.2106, Train Acc : 96.0938, Test Acc : 93.4200
# Iteration : 360 - Train Loss : 0.2422, Test Loss : 0.2403, Train Acc : 91.4062, Test Acc : 92.5900
# Epoch 111 Started...
# Iteration : 60 - Train Loss : 0.1444, Test Loss : 0.1944, Train Acc : 96.0938, Test Acc : 94.1100
# Iteration : 120 - Train Loss : 0.0727, Test Loss : 0.2739, Train Acc : 97.6562, Test Acc : 92.1900
# Iteration : 180 - Train Loss : 0.1685, Test Loss : 0.2736, Train Acc : 92.9688, Test Acc : 91.7300
# Iteration : 240 - Train Loss : 0.1980, Test Loss : 0.2456, Train Acc : 96.0938, Test Acc : 92.4500
# Iteration : 300 - Train Loss : 0.1958, Test Loss : 0.2215, Train Acc : 93.7500, Test Acc : 93.2900
# Iteration : 360 - Train Loss : 0.1207, Test Loss : 0.2236, Train Acc : 96.0938, Test Acc : 93.1400
# Epoch 121 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.1269, Test Loss : 0.1553, Train Acc : 95.3125, Test Acc : 95.1700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0806, Test Loss : 0.1417, Train Acc : 97.6562, Test Acc : 95.6700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0687, Test Loss : 0.1414, Train Acc : 97.6562, Test Acc : 95.7700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 240 - Train Loss : 0.0648, Test Loss : 0.1401, Train Acc : 98.4375, Test Acc : 95.8200
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.0709, Test Loss : 0.1378, Train Acc : 96.8750, Test Acc : 95.9000
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.0715, Test Loss : 0.1404, Train Acc : 96.0938, Test Acc : 95.9200
# Epoch 131 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0441, Test Loss : 0.1299, Train Acc : 98.4375, Test Acc : 96.3200
# Iteration : 120 - Train Loss : 0.0673, Test Loss : 0.1292, Train Acc : 98.4375, Test Acc : 96.3000
# Iteration : 180 - Train Loss : 0.0060, Test Loss : 0.1333, Train Acc : 100.0000, Test Acc : 96.2500
# Iteration : 240 - Train Loss : 0.0162, Test Loss : 0.1374, Train Acc : 100.0000, Test Acc : 96.1600
# Iteration : 300 - Train Loss : 0.0376, Test Loss : 0.1342, Train Acc : 99.2188, Test Acc : 96.2300
# Iteration : 360 - Train Loss : 0.0527, Test Loss : 0.1350, Train Acc : 98.4375, Test Acc : 96.0300
# Epoch 141 Started...
# Iteration : 60 - Train Loss : 0.0266, Test Loss : 0.1477, Train Acc : 99.2188, Test Acc : 95.9200
# Iteration : 120 - Train Loss : 0.0126, Test Loss : 0.1413, Train Acc : 100.0000, Test Acc : 96.2500
# Iteration : 180 - Train Loss : 0.0286, Test Loss : 0.1348, Train Acc : 99.2188, Test Acc : 96.2900
# Iteration : 240 - Train Loss : 0.0576, Test Loss : 0.1308, Train Acc : 98.4375, Test Acc : 96.3000
# Iteration : 300 - Train Loss : 0.0439, Test Loss : 0.1368, Train Acc : 99.2188, Test Acc : 96.2600
# Iteration : 360 - Train Loss : 0.0368, Test Loss : 0.1406, Train Acc : 97.6562, Test Acc : 96.2000
# Epoch 151 Started...
# Iteration : 60 - Train Loss : 0.0286, Test Loss : 0.1427, Train Acc : 99.2188, Test Acc : 96.0400
# Iteration : 120 - Train Loss : 0.1427, Test Loss : 0.1357, Train Acc : 93.7500, Test Acc : 96.1300
# Iteration : 180 - Train Loss : 0.0286, Test Loss : 0.1393, Train Acc : 98.4375, Test Acc : 96.0600
# Iteration : 240 - Train Loss : 0.0457, Test Loss : 0.1356, Train Acc : 97.6562, Test Acc : 96.1700
# Iteration : 300 - Train Loss : 0.0562, Test Loss : 0.1382, Train Acc : 98.4375, Test Acc : 96.1100
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 360 - Train Loss : 0.0442, Test Loss : 0.1343, Train Acc : 97.6562, Test Acc : 96.3400
# Epoch 161 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0299, Test Loss : 0.1381, Train Acc : 99.2188, Test Acc : 96.3700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0111, Test Loss : 0.1345, Train Acc : 100.0000, Test Acc : 96.4900
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 180 - Train Loss : 0.0314, Test Loss : 0.1326, Train Acc : 99.2188, Test Acc : 96.5100
# Iteration : 240 - Train Loss : 0.0157, Test Loss : 0.1307, Train Acc : 99.2188, Test Acc : 96.4600
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 300 - Train Loss : 0.0231, Test Loss : 0.1286, Train Acc : 99.2188, Test Acc : 96.5700
# Iteration : 360 - Train Loss : 0.0421, Test Loss : 0.1281, Train Acc : 97.6562, Test Acc : 96.5600
# Epoch 171 Started...
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 60 - Train Loss : 0.0089, Test Loss : 0.1234, Train Acc : 100.0000, Test Acc : 96.8500
# Iteration : 120 - Train Loss : 0.0181, Test Loss : 0.1257, Train Acc : 99.2188, Test Acc : 96.6400
# Iteration : 180 - Train Loss : 0.0723, Test Loss : 0.1259, Train Acc : 98.4375, Test Acc : 96.7100
# Iteration : 240 - Train Loss : 0.0583, Test Loss : 0.1230, Train Acc : 97.6562, Test Acc : 96.7600
# Iteration : 300 - Train Loss : 0.0038, Test Loss : 0.1210, Train Acc : 100.0000, Test Acc : 96.7600
# Iteration : 360 - Train Loss : 0.0138, Test Loss : 0.1232, Train Acc : 100.0000, Test Acc : 96.7300
# Epoch 181 Started...
# Iteration : 60 - Train Loss : 0.0032, Test Loss : 0.1195, Train Acc : 100.0000, Test Acc : 96.7600
# Iteration : 120 - Train Loss : 0.0153, Test Loss : 0.1196, Train Acc : 99.2188, Test Acc : 96.8500
# Iteration : 180 - Train Loss : 0.0108, Test Loss : 0.1211, Train Acc : 99.2188, Test Acc : 96.7600
# Iteration : 240 - Train Loss : 0.0233, Test Loss : 0.1208, Train Acc : 99.2188, Test Acc : 96.7200
# Iteration : 300 - Train Loss : 0.0035, Test Loss : 0.1226, Train Acc : 100.0000, Test Acc : 96.7500
# Iteration : 360 - Train Loss : 0.0156, Test Loss : 0.1231, Train Acc : 99.2188, Test Acc : 96.7500
# Epoch 191 Started...
# Iteration : 60 - Train Loss : 0.0267, Test Loss : 0.1206, Train Acc : 99.2188, Test Acc : 96.8300
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0039, Test Loss : 0.1186, Train Acc : 100.0000, Test Acc : 96.9500
# Iteration : 180 - Train Loss : 0.0349, Test Loss : 0.1206, Train Acc : 99.2188, Test Acc : 96.8000
# Iteration : 240 - Train Loss : 0.0415, Test Loss : 0.1204, Train Acc : 99.2188, Test Acc : 96.8400
# Iteration : 300 - Train Loss : 0.0189, Test Loss : 0.1221, Train Acc : 99.2188, Test Acc : 96.7900
# Iteration : 360 - Train Loss : 0.0098, Test Loss : 0.1242, Train Acc : 100.0000, Test Acc : 96.6900
# Epoch 201 Started...
# Iteration : 60 - Train Loss : 0.0063, Test Loss : 0.1197, Train Acc : 100.0000, Test Acc : 96.8700
#
# *********************************** Best Acc Updated ***********************************
# Iteration : 120 - Train Loss : 0.0048, Test Loss : 0.1191, Train Acc : 100.0000, Test Acc : 96.9800
# Iteration : 180 - Train Loss : 0.0606, Test Loss : 0.1184, Train Acc : 97.6562, Test Acc : 96.9600
# Iteration : 240 - Train Loss : 0.0049, Test Loss : 0.1182, Train Acc : 100.0000, Test Acc : 96.9300
# Iteration : 300 - Train Loss : 0.0254, Test Loss : 0.1201, Train Acc : 99.2188, Test Acc : 96.8500
# Iteration : 360 - Train Loss : 0.0143, Test Loss : 0.1223, Train Acc : 99.2188, Test Acc : 96.8500

# %%
plt.figure(figsize=(20, 20))
plt.rcParams['axes.titlesize'] = 30
plt.axis('off')

label_fontsize = 25

plt.subplot(2, 1, 1)
train_lossline, = plt.plot(WRN_28_10.train_losses, label='Train')
test_lossline, = plt.plot(WRN_28_10.test_losses, color='red', label='Test')
plt.legend(handles=[train_lossline, test_lossline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Loss', fontsize=label_fontsize)

plt.subplot(2, 1, 2)
train_accline, = plt.plot(WRN_28_10.train_acc, label='Train')
test_accline, = plt.plot(WRN_28_10.test_acc, color='red', label='Test')
plt.legend(handles=[train_accline, test_accline], fontsize=20)
plt.xlabel('Step', fontsize=label_fontsize)
plt.ylabel('Accuracy', fontsize=label_fontsize)
# Out:
# Text(0, 0.5, 'Accuracy')
